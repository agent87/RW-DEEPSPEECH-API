# %%
import requests

# %%
with open('arn.wav', 'rb') as file:
    audio_bytes = file.read()

# %%
url = "http://localhost:6000/transcribe"



audio_file = {'audio_bytes': audio_bytes}

response = requests.post(url, files=audio_file)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /opt/anaconda3/envs/tts-rw/lib/python3.10/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File /opt/anaconda3/envs/tts-rw/lib/python3.10/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File /opt/anaconda3/envs/tts-rw/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
# ...

# %%
response.status_code
# Out:
# {'sentences': "mwaramutse mumeze mute n'igerageza turi gukora"}

# %%
import os

file_path = "stt/sounds/sound-0.wav"

# %%
os.access(file_path, os.R_OK)
# Out:
# True

# %%
os.path.isfile(file_path)
# Out:
# True

# %%
os.
